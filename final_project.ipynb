# %% [markdown]
# # **Final project**

# %% [markdown]
# ### **Dataset description**

# %% [markdown]
# * `Host related columns`:
#
# host_id,
# host_name,
# host_since,
# host_location,
# host_about,
# host_response_time,
# host_response_rate,
# host_acceptance_rate,
# host_is_superhost,
# host_thumbnail_url,
# host_picture_url,
# host_neighbourhood,
# host_listings_count,
# host_total_listings_count,
# host_verifications,
# host_has_profile_pic,
# host_identity_verified,
# host_url.
#
# * `Property and room features`:
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
#
# * `Location based columns`:
# latitude
# longitude
# zipcode
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# country
# country_code
# market
# smart_location
#
# * `Price and cost fields`:
#
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# extra_people
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
#
# * `Review metrics`:
#
# number_of_reviews
# number_of_reviews_ltm
# number_of_reviews_l30d
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# reviews_per_month
#
# * `Metadata and URLs`:
# id
# name
# listing_url
# description
# summary
# space
# neighborhood_overview
# picture_url
# calendar_updated
# scrape_id
# last_scraped
# source
# license
#
# * `Experience and Misc`:
# experiences_offered
# is_location_exact
# requires_license
# instant_bookable
# is_business_travel_ready

# %% [markdown]
# ### **Importing main libraries**

# %%
# !pip install textblob keybert scikit-learn folium plotly
# Out:
# Requirement already satisfied: textblob in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (0.18.0.post0)
# Requirement already satisfied: keybert in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: scikit-learn in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: folium in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (0.14.0)
# Requirement already satisfied: plotly in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (6.0.1)
# Requirement already satisfied: nltk>=3.8 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from keybert) (1.26.4)
# Requirement already satisfied: rich>=10.4.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from keybert) (14.0.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from keybert) (5.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: branca>=0.6.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from folium) (2.32.4)
# Requirement already satisfied: narwhals>=1.15.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from plotly) (1.31.0)
# Requirement already satisfied: packaging in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from plotly) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: click in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from nltk>=3.8->textblob) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from nltk>=3.8->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from nltk>=3.8->textblob) (4.67.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from rich>=10.4.0->keybert) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (4.49.0)
# Requirement already satisfied: torch>=1.11.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (0.31.2)
# Requirement already satisfied: Pillow in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (4.14.1)
# Requirement already satisfied: filelock in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2024.12.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.13.3)
# Requirement already satisfied: networkx in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.4.2)
# Requirement already satisfied: setuptools in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from requests->folium) (2025.6.15)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.stats import f_oneway
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.express as px
import folium

# %% [markdown]
# ### **Data inspection**

# %%
df = pd.read_csv('listings.csv')
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  36121  https://www.airbnb.com/rooms/36121  20250301213336   2025-03-03
# 1  36647  https://www.airbnb.com/rooms/36647  20250301213336   2025-03-03
# 2  38663  https://www.airbnb.com/rooms/38663  20250301213336   2025-03-02
# 3  38833  https://www.airbnb.com/rooms/38833  20250301213336   2025-03-03
# 4  39282  https://www.airbnb.com/rooms/39282  20250301213336   2025-03-02
#
#         source                                               name  \
# 0  city scrape                 Lg Rm in Historic Prospect Heights
# 1  city scrape  1 Bedroom & your own Bathroom, Elevator Apartment
# 2  city scrape                   Luxury Brownstone in Boerum Hill
# 3  city scrape                 Spectacular West Harlem Garden Apt
# 4  city scrape                    “Work-from-home” from OUR home.
#
#                                          description  \
# 0  Cozy space share in the heart of a great neigh...
# 1  Private bedroom with your own bathroom in a 2 ...
# 2  Beautiful, large home in great hipster neighbo...
# 3  This is a very large and unique  space. An inc...
# 4  *Monthly Discount will automatically apply <br...
#
#                                neighborhood_overview  \
# 0  Full of tree-lined streets and beautiful brown...
# 1   Manhattan, SE corner of 2nd Ave/ E. 110th street
# 2  diverse, lively, hip, cool: loaded with restau...
# 3  West Harlem is now packed with great restauran...
# 4  THE NEIGHBORHOOD:<br />Our apartment is locate...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/8776354/35b32...    62165  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   157798  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...   165789  ...
# 3  https://a0.muscache.com/pictures/7554f9e5-4ab0...   166532  ...
# 4  https://a0.muscache.com/pictures/ef8f43ad-d967...   168525  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   5.00                5.00
# 1                        4.90                   4.38                4.71
# 2                        4.88                   4.86                4.62
# 3                        4.96                   4.79                4.82
# 4                        4.88                   4.85                4.78
#
#               license instant_bookable calculated_host_listings_count  \
# 0                 NaN                f                              1
# 1                 NaN                f                              1
# 2  OSE-STRREG-0001784                f                              1
# 3  OSE-STRREG-0000476                f                              1
# 4  OSE-STRREG-0001150                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.05
# 1                                           0              0.58
# 2                                           0              0.28
# 3                                           0              1.36
# 4                                           0              1.54
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37434 entries, 0 to 37433
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            37434 non-null  int64
#  1   listing_url                                   37434 non-null  object
#  2   scrape_id                                     37434 non-null  int64
#  3   last_scraped                                  37434 non-null  object
#  4   source                                        37434 non-null  object
#  5   name                                          37432 non-null  object
#  6   description                                   36441 non-null  object
#  7   neighborhood_overview                         20224 non-null  object
#  8   picture_url                                   37433 non-null  object
#  9   host_id                                       37434 non-null  int64
#  10  host_url                                      37434 non-null  object
#  11  host_name                                     37396 non-null  object
#  12  host_since                                    37396 non-null  object
#  13  host_location                                 29747 non-null  object
#  14  host_about                                    21455 non-null  object
#  15  host_response_time                            21286 non-null  object
#  16  host_response_rate                            21286 non-null  object
#  17  host_acceptance_rate                          22740 non-null  object
#  18  host_is_superhost                             36994 non-null  object
#  19  host_thumbnail_url                            37396 non-null  object
#  20  host_picture_url                              37396 non-null  object
#  21  host_neighbourhood                            29718 non-null  object
#  22  host_listings_count                           37396 non-null  float64
#  23  host_total_listings_count                     37396 non-null  float64
#  24  host_verifications                            37396 non-null  object
#  25  host_has_profile_pic                          37396 non-null  object
#  26  host_identity_verified                        37396 non-null  object
#  27  neighbourhood                                 20225 non-null  object
#  28  neighbourhood_cleansed                        37434 non-null  object
#  29  neighbourhood_group_cleansed                  37434 non-null  object
#  30  latitude                                      37434 non-null  float64
#  31  longitude                                     37434 non-null  float64
#  32  property_type                                 37434 non-null  object
#  33  room_type                                     37434 non-null  object
#  34  accommodates                                  37434 non-null  int64
#  35  bathrooms                                     22503 non-null  float64
#  36  bathrooms_text                                37404 non-null  object
#  37  bedrooms                                      31523 non-null  float64
#  38  beds                                          22352 non-null  float64
#  39  amenities                                     37434 non-null  object
#  40  price                                         22308 non-null  object
#  41  minimum_nights                                37434 non-null  int64
#  42  maximum_nights                                37434 non-null  int64
#  43  minimum_minimum_nights                        37431 non-null  float64
#  44  maximum_minimum_nights                        37431 non-null  float64
#  45  minimum_maximum_nights                        37431 non-null  float64
#  46  maximum_maximum_nights                        37431 non-null  float64
#  47  minimum_nights_avg_ntm                        37431 non-null  float64
#  48  maximum_nights_avg_ntm                        37431 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              32057 non-null  object
#  51  availability_30                               37434 non-null  int64
#  52  availability_60                               37434 non-null  int64
#  53  availability_90                               37434 non-null  int64
#  54  availability_365                              37434 non-null  int64
#  55  calendar_last_scraped                         37434 non-null  object
#  56  number_of_reviews                             37434 non-null  int64
#  57  number_of_reviews_ltm                         37434 non-null  int64
#  58  number_of_reviews_l30d                        37434 non-null  int64
#  59  availability_eoy                              37434 non-null  int64
#  60  number_of_reviews_ly                          37434 non-null  int64
#  61  estimated_occupancy_l365d                     37434 non-null  int64
#  62  estimated_revenue_l365d                       22308 non-null  float64
#  63  first_review                                  25647 non-null  object
#  64  last_review                                   25647 non-null  object
#  65  review_scores_rating                          25647 non-null  float64
#  66  review_scores_accuracy                        25636 non-null  float64
#  67  review_scores_cleanliness                     25646 non-null  float64
#  68  review_scores_checkin                         25632 non-null  float64
#  69  review_scores_communication                   25641 non-null  float64
#  70  review_scores_location                        25629 non-null  float64
#  71  review_scores_value                           25630 non-null  float64
#  72  license                                       5369 non-null   object
#  73  instant_bookable                              37434 non-null  object
#  74  calculated_host_listings_count                37434 non-null  int64
#  75  calculated_host_listings_count_entire_homes   37434 non-null  int64
#  76  calculated_host_listings_count_private_rooms  37434 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   37434 non-null  int64
#  78  reviews_per_month                             25647 non-null  float64
# dtypes: float64(23), int64(20), object(36)
# memory usage: 22.6+ MB

# %%
# listing all columns
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# * I can't tell the diff between host_listings_count and host_total_listings_count. I think one of them could be dropped?

# %%
# getting all unique values for host_listings_count
df['host_listings_count'].unique()
# Out:
# array([1.000e+00, 2.000e+00, 7.000e+00, 4.000e+00, 3.000e+00, 6.000e+00,
#        5.000e+00, 1.100e+01, 2.900e+01, 1.500e+01, 1.300e+01, 1.400e+01,
#        9.000e+00, 2.500e+01,       nan, 1.700e+01, 8.000e+00, 2.400e+01,
#        1.900e+01, 1.200e+01, 2.200e+01, 2.640e+02, 3.900e+01, 1.000e+01,
#        3.100e+01, 7.600e+01, 6.800e+01, 2.100e+01, 3.000e+01, 1.600e+01,
#        6.190e+02, 3.030e+02, 2.000e+01, 1.770e+02, 1.760e+02, 2.100e+02,
#        5.200e+01, 1.800e+01, 4.500e+01, 2.130e+02, 3.500e+01, 5.500e+01,
#        8.000e+01, 1.080e+02, 1.190e+02, 2.010e+02, 2.560e+03, 8.100e+01,
#        3.170e+02, 1.730e+02, 3.498e+03, 1.399e+03, 9.900e+01, 6.500e+01,
#        2.350e+02, 2.473e+03, 2.100e+02, 4.600e+01, 7.300e+01, 5.928e+03,
#        1.220e+02, 8.450e+02, 1.664e+03, 9.000e+01, 1.296e+03, 6.900e+01,
#        9.830e+02, 5.120e+02, 3.580e+02, 1.210e+02, 3.290e+02, 1.000e+02,
#        1.160e+02, 4.533e+03, 1.020e+03, 5.758e+03, 1.433e+03, 6.100e+01,
#        1.180e+02, 1.100e+02, 3.070e+02])

# %%
# getting all values for neighboorhood
df['neighbourhood'].unique()
# Out:
# array(['Neighborhood highlights', nan], dtype=object)

# %% [markdown]
# * Neighbourhood should be dropped

# %%
# getting all values for neighbourhood_cleansed
df['neighbourhood_cleansed'].unique()
# Out:
# array(['Prospect Heights', 'East Harlem', 'Boerum Hill', 'Harlem',
#        'Williamsburg', "Hell's Kitchen", 'Midtown', 'Fort Greene',
#        'Bedford-Stuyvesant', 'Sunnyside', 'Crown Heights', 'Clinton Hill',
#        'Chelsea', 'Washington Heights', 'Gowanus', 'West Village',
#        'Lower East Side', 'Carroll Gardens', 'Flatbush', 'East Village',
#        'Greenpoint', 'Ridgewood', 'Mott Haven', 'Morningside Heights',
#        'Rockaway Beach', 'Park Slope', 'Upper East Side', 'Kips Bay',
#        'Ditmars Steinway', 'Middle Village', 'Astoria', 'Jamaica',
#        'South Slope', 'Brooklyn Heights', 'Upper West Side',
#        'East Flatbush', 'Greenwich Village', 'Bushwick', 'Chinatown',
#        'Emerson Hill', 'Bensonhurst', 'Clason Point', 'Eastchester',
#        'Windsor Terrace', 'Gravesend', 'Shore Acres', 'Nolita',
#        'Vinegar Hill', 'Kingsbridge', 'Gramercy', 'Sheepshead Bay',
#        'Long Island City', 'Sunset Park', 'Prospect-Lefferts Gardens',
#        'Downtown Brooklyn', 'Little Italy', 'Tribeca', 'SoHo',
#        'Brighton Beach', 'Elmhurst', 'Theater District', 'Rego Park',
#        'Co-op City', 'Kensington', 'Woodside', 'East New York', 'Inwood',
#        'Murray Hill', 'Maspeth', 'Spuyten Duyvil', 'Battery Park City',
#        'Briarwood', 'Red Hook', 'Two Bridges', 'Fort Hamilton',
#        'Tompkinsville', 'Jackson Heights', 'New Springville',
#        'Columbia St', 'Allerton', 'East Elmhurst', 'Tottenville',
#        'Cobble Hill', 'Bayside', 'College Point', 'Concord', 'Flushing',
#        'Melrose', 'DUMBO', 'City Island', 'Bay Ridge', 'Norwood',
#        'Concourse', 'Port Morris', 'Arverne', 'Richmond Hill', 'Glendale',
#        'Longwood', 'Williamsbridge', 'Financial District', 'Soundview',
#        'Queens Village', 'Canarsie', 'Parkchester', 'Bronxdale', 'NoHo',
#        'Sea Gate', 'Flatlands', 'Bay Terrace', 'Ozone Park', 'Woodhaven',
#        'Clifton', 'Fieldston', 'Borough Park', 'Mount Hope', 'Huguenot',
#        'Concourse Village', 'Forest Hills', 'Wakefield', 'Midwood',
#        'St. George', 'Civic Center', 'Roosevelt Island',
#        'Lighthouse Hill', 'Randall Manor', 'Unionport', 'Kew Gardens',
#        'Bellerose', 'Flatiron District', 'Morris Park', 'Stuyvesant Town',
#        'South Ozone Park', 'East Morrisania', 'Tremont', 'Cypress Hills',
#        'West Brighton', 'Jamaica Estates', 'Manhattan Beach',
#        'Springfield Gardens', 'Marble Hill', 'Fordham', 'Belmont',
#        'Brownsville', 'Castleton Corners', 'Hunts Point', 'Howard Beach',
#        'Fresh Meadows', 'Great Kills', 'Riverdale', 'Morrisania',
#        'Grymes Hill', 'Holliswood', 'Corona', 'Edgemere', 'New Brighton',
#        'Baychester', 'Pelham Gardens', 'Laurelton', 'Olinville',
#        'Navy Yard', 'Coney Island', 'St. Albans', 'Stapleton',
#        'Claremont Village', 'Highbridge', 'South Beach', 'Rosedale',
#        'Howland Hook', 'Cambria Heights', 'Kew Gardens Hills',
#        'Dyker Heights', 'Oakwood', 'Arrochar', 'Hollis', 'Whitestone',
#        'Edenwald', 'Bath Beach', 'North Riverdale', 'Mount Eden',
#        'Morris Heights', 'Fort Wadsworth', 'Pelham Bay', 'New Dorp',
#        'Westchester Square', 'Far Rockaway', 'Port Richmond', 'Neponsit',
#        'Throgs Neck', 'Country Club', 'Mariners Harbor', 'Willowbrook',
#        'Mill Basin', 'Douglaston', 'Midland Beach', 'Bergen Beach',
#        'Schuylerville', 'New Dorp Beach', 'Rosebank', 'Arden Heights',
#        'Grant City', 'Jamaica Hills', "Prince's Bay", 'Bayswater',
#        "Bull's Head", 'University Heights', 'Woodlawn', 'Belle Harbor',
#        'Silver Lake', 'Gerritsen Beach', 'Breezy Point', 'Westerleigh',
#        'Graniteville', 'Chelsea, Staten Island', 'Dongan Hills',
#        'Van Nest', 'Castle Hill', 'West Farms', 'Todt Hill',
#        'Eltingville', 'Woodrow', 'Rossville',
#        'Bay Terrace, Staten Island', 'Little Neck'], dtype=object)

# %% [markdown]
# * Now what is the deal with 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm'? Something can be dropped from here if there is redundancy.

# %%
# getting all unique values for maximum_maximum_nights
df['maximum_maximum_nights'].unique()
# Out:
# array([3.65000000e+02, 9.99000000e+02, 6.00000000e+01, 1.12500000e+03,
#        4.50000000e+01, 1.20000000e+02, 1.80000000e+02, 1.50000000e+02,
#        9.00000000e+01, 4.00000000e+01, 3.00000000e+01, 2.40000000e+02,
#        7.30000000e+02, 3.10000000e+01, 3.00000000e+03, 1.00000000e+02,
#        3.60000000e+02, 5.90000000e+01, 7.50000000e+01, 2.90000000e+01,
#        2.50000000e+01, 4.80000000e+02, 6.80000000e+01, 2.50000000e+02,
#        2.80000000e+01, 2.70000000e+02, 3.20000000e+01, 1.00000000e+03,
#        8.90000000e+01, 2.00000000e+02, 5.18000000e+02, 7.60000000e+02,
#        3.00000000e+02, 1.01000000e+02, 1.00000000e+01, 7.00000000e+01,
#        6.000e+02, 2.590e+02, 3.800e+01, 1.400e+02, 6.400e+01, 9.400e+01,
#        3.360e+02, 3.300e+01, 3.560e+02, 7.000e+02, 1.200e+01, 2.100e+01,
#        3.400e+01, 3.010e+02, 1.210e+02, 1.250e+02, 3.220e+02, 4.700e+01,
#        2.800e+01, 7.200e+02, 3.020e+02, 6.200e+01, 2.000e+01, 1.270e+02,
#        1.300e+01, 1.650e+02, 7.290e+02, 2.450e+02, 3.700e+01, 1.100e+01,
#        2.120e+02, 8.100e+01, 4.100e+01, 1.600e+01, 3.300e+02])

# %% [markdown]
# * Don't know what this means: 'availability_eoy'

# %%
# checking for unique values in avaliability_eoy
df['availability_eoy'].unique()
# Out:
# array([301, 143, 267,  25,  38, 305, 304, 113,  83, 204,   0, 129,  91,
#        160,  85,  48, 116, 173,  89, 303,  77,  30,  50, 243,  90, 146,
#        118, 257,  84, 139, 220,  57, 177, 294, 203, 240,  88, 166,  20,
#        155, 112,  71, 150,  59, 297, 213,  33, 181, 180, 153, 298, 244,
#         92, 232, 156, 183, 239, 152, 281,  41, 245,  14,  76, 279, 122,
#        163,  21,  45,  65, 215,  32, 270,  87, 255,   2,   4, 107,  61,
#        269, 277,   1, 235, 212,  52, 237, 275, 227, 274,   9, 184, 302,
#        241, 295, 159, 264, 178, 179, 216, 124, 256, 254, 169, 233,  70,
#        109,  23, 189, 192, 238,  75,  94, 265, 193, 136, 211,  42, 198,
#        276, 221,  96, 246, 199, 114, 263, 185, 289, 186, 290,  17, 151,
#        137, 171, 170,  73,  35, 247, 154,  44,  58,  40,  82, 104, 121,
#        268, 291, 175, 299, 206, 273,  12, 210,  62, 251, 296, 272, 197,
#        149, 123, 102,  56, 248, 126, 205,  93, 119,  43, 145,  60, 135,
#        207, 214, 292, 194, 182,  95, 100, 101, 223,  74, 222,  36, 260,
#        261, 125,  31,  37, 128,   8, 201, 191, 176, 196,  49, 134, 187,
#          5,  53, 172, 228,  69, 147, 280, 218, 217,  13, 288, 242, 230,
#        168, 266, 234, 252, 219, 285,  28,  26, 165, 140, 271,  66, 249,
#        174, 131, 117, 202,  19, 106, 195, 138, 167,  98, 188,  80, 142,
#        300,  86, 253,  97, 115, 103,  34,  18,  63, 158, 108, 229,  11,
#        226, 190, 110,  47,  64,   3, 157, 284, 208,  29,  81, 283, 286,
#        105, 144, 162,  79, 133, 278, 224, 262,  54,  78,   7, 231, 127,
#         99, 148, 209,  55,  16,  72, 130, 293,   6, 282, 161, 236,  10,
#         67,  68,  46,  22, 120, 250, 287,  51, 225, 200,  27,  39, 258,
#         15, 259,  24, 111, 164, 141, 132])

# %% [markdown]
# * This only has 2 vals, I'll drop it also.

# %%
# checking for unique values in calendar_last_scraped
df['calendar_last_scraped'].unique()
# Out:
# array(['2025-03-03', '2025-03-02'], dtype=object)

# %% [markdown]
# * Again there might be redundancy here: 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'number_of_reviews_ly'. I think that if number_of_reviews means the total number of reviews we can only keep this one. The other ones are not really relevant unless the analysis goes in that direction :)

# %% [markdown]
# * I think the estimated_occupancy_l365d column means the number of days in the last year when the property was booked/occupied? I would VERY MUCH like to drop it :)

# %%
# checking the unique values for estimated_occupancyl365d
df['estimated_occupancy_l365d'].unique()
# Out:
# array([  0, 255, 154, 180,  60, 124, 168, 120,  62, 240,  56, 192, 141,
#        186, 205, 179,  13,  38, 115,  51,  26, 102, 218, 170, 243,  64,
#        128,  42, 130, 150,  98, 220, 230,  77, 166,  90,  28, 248, 210,
#        140, 160, 118,  84,  92,  70, 238, 252, 114,  14, 236,  80, 126,
#         48, 112, 216, 234,  74, 200,  20, 100, 182])

# %% [markdown]
# * This column feels relevant BUT I think this can be preprocessed to a has_licence column (nans become 0s and the rest of them become 1s), assuming that the nans in this column mean that the property has no licence.
# UPDATE: According to CHAT GPT in some cities Airbnb hosts are required by law to register and obtain a licence before they can legally rent their property. The licence field is optional in many regions, so for many listings it's simply NaN. This means that:
#     - license depends on the location
#     - engineering the has_licence feature would extract the meaningful structure of it in a way that supports our analysis

# %%
# chacking unique values for license
df['license'].unique()
# Out:
# array([nan, 'OSE-STRREG-0001784', 'OSE-STRREG-0000476', ...,
#        'OSE-STRREG-0002922', 'OSE-STRREG-0002813', 'OSE-STRREG-0002894'],
#       dtype=object)

# %% [markdown]
# * Does reviews_per_month mean average number of reviews per month or something else?

# %%
# checking unique values for reviews_per_month
df['reviews_per_month'].unique()
# Out:
# array([5.0000e-02, 5.8000e-01, 2.8000e-01, 1.3600e+00, 1.5400e+00,
#        2.5000e-01, 2.6000e-01, 1.0100e+00, 3.0000e-02, 1.3400e+00,
#        7.0000e-02, 2.1600e+00, 2.0000e-01, 1.0300e+00, 9.5000e-01,
#        1.1000e-01, 8.9000e-01, 7.4000e-01, 2.3000e-01, 2.1000e-01,
#        1.9100e+00, 3.9000e-01, 1.2500e+00, 4.0000e-02, 1.3200e+00,
#        7.1000e-01, 3.1000e-01, 4.5000e-01,        nan, 1.7000e+00,
#        4.3000e-01, 9.7000e-01, 2.9000e-01, 3.3000e-01, 4.4200e+00,
#        8.0000e-02, 7.8000e-01, 1.6900e+00, 1.0000e-01, 2.8100e+00,
#        2.1100e+00, 1.0000e-02, 1.0700e+00, 1.6500e+00, 4.2000e-01,
#        1.7000e-01, 1.6000e+00, 1.5800e+00, 3.0000e-01, 9.0000e-01,
#        1.4700e+00, 3.8000e-01, 9.0000e-02, 3.2000e-01, 6.1000e-01,
#        1.9000e-01, 1.1000e+00, 6.8000e-01, 8.3000e-01, 5.2000e-01,
#        1.1200e+00, 3.5000e-01, 1.7400e+00, 9.4000e-01, 1.7700e+00,
#        1.1800e+00, 2.6700e+00, 1.4000e-01, 2.4000e-01, 1.5700e+00,
#        1.1700e+00, 2.7000e-01, 1.3000e-01, 1.8000e-01, 7.5000e-01,
#        1.9800e+00, 4.9000e-01, 2.2400e+00, 4.0700e+00, 2.5500e+00,
#        2.0000e-02, 3.3700e+00, 1.6700e+00, 2.2000e-01, 1.1600e+00,
#        8.4200e+00, 1.3150e+01, 1.0150e+01, 2.1770e+01, 2.3520e+01,
#        4.9300e+00, 1.1160e+01, 1.0900e+01, 6.4600e+00, 7.9400e+00,
#        6.3400e+00, 7.0400e+00, 5.6700e+00, 6.0700e+00, 5.3800e+00,
#        2.0290e+01, 9.5400e+00, 8.1000e+00, 6.9900e+00, 4.2200e+00,
#        6.2100e+00, 5.7100e+00, 8.6100e+00, 4.3300e+00, 6.4000e+00,
#        5.8700e+00, 8.9500e+00, 1.0940e+01, 7.7300e+00, 8.0000e+00,
#        6.8400e+00, 9.2500e+00, 6.5000e+00, 5.1100e+00, 5.9300e+00,
#        5.2200e+00, 1.4000e+01, 2.1000e+01, 2.5000e+01, 9.0000e+00,
#        7.0000e+00, 1.5000e+01])

# %% [markdown]
# * I assume this means false and true, this would need some preprocessing into binary, but it has so many missing vals :( I'll see what I can do with it

# %%
# checking the unique values for instant_bookable
df['instant_bookable'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# `To drop`: id, listing_url, scrape_id, last_scraped, source, host_neighbourhood, picture_url, host_id, host_name, host_location, host_about, host_thumbnail_url, host_picture_url, host_has_profile_pic, host_neighbourhood, host_url, host_response_time    host_response_rate, host_acceptance_rate, bathrooms_text, neighbourhood, calendar_updated, calendar_last_scraped, estimated_occupancy_l365d

# %%
columns_to_drop = [
    'id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'host_neighbourhood', 'picture_url', 'host_id', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_has_profile_pic', 'host_url', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'bathrooms_text', 'neighbourhood', 'calendar_updated', 'calendar_last_scraped', 'host_total_listings_count', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'neighbourhood_group_cleansed', 'has_availability', 'availability_60', 'availability_90', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'neighborhood_overview', 'property_type'
]
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['name', 'description', 'host_since', 'host_is_superhost',
#        'host_listings_count', 'host_verifications', 'host_identity_verified',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_365', 'number_of_reviews', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_value', 'license',
#        'instant_bookable', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ### **Dealing with missing values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37434 entries, 0 to 37433
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       37432 non-null  object
#  1   description                36441 non-null  object
#  2   host_since                 37396 non-null  object
#  3   host_is_superhost          36994 non-null  object
#  4   host_listings_count        37396 non-null  float64
#  5   host_verifications         37396 non-null  object
#  6   host_identity_verified     37396 non-null  object
#  7   neighbourhood_cleansed     37434 non-null  object
#  8   latitude                   37434 non-null  float64
#  9   longitude                  37434 non-null  float64
#  10  room_type                  37434 non-null  object
#  11  accommodates               37434 non-null  int64
#  12  bathrooms                  22503 non-null  float64
#  13  bedrooms                   31523 non-null  float64
#  14  beds                       22352 non-null  float64
#  15  amenities                  37434 non-null  object
#  16  price                      22308 non-null  object
#  17  minimum_nights             37434 non-null  int64
#  18  maximum_nights             37434 non-null  int64
#  19  availability_30            37434 non-null  int64
#  20  availability_365           37434 non-null  int64
#  21  number_of_reviews          37434 non-null  int64
#  22  availability_eoy           37434 non-null  int64
#  23  number_of_reviews_ly       37434 non-null  int64
#  24  estimated_occupancy_l365d  37434 non-null  int64
#  25  estimated_revenue_l365d    22308 non-null  float64
#  26  first_review               25647 non-null  object
#  27  last_review                25647 non-null  object
#  28  review_scores_rating       25647 non-null  float64
#  29  review_scores_value        25630 non-null  float64
#  30  license                    5369 non-null   object
#  31  instant_bookable           37434 non-null  object
#  32  reviews_per_month          25647 non-null  float64
# dtypes: float64(10), int64(9), object(14)
# memory usage: 9.4+ MB

# %%
# printing the columns that have more than 0 missing values
missing_columns = df.columns[df.isna().any()].tolist()
print("Columns with missing values:", missing_columns)

# printing missing values in order of the number of missing values
missing_values = df[missing_columns].isna().sum().sort_values(ascending=False)
print("Missing values in each column:\n", missing_values)
# Out:
# Columns with missing values: ['name', 'description', 'host_since', 'host_is_superhost', 'host_listings_count', 'host_verifications', 'host_identity_verified', 'bathrooms', 'bedrooms', 'beds', 'price', 'estimated_revenue_l365d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_value', 'license', 'reviews_per_month']
# Missing values in each column:
#  license                    32065
# price                      15126
# estimated_revenue_l365d    15126
# beds                       15082
# bathrooms                  14931
# review_scores_value        11804
# review_scores_rating       11787
# last_review                11787
# first_review               11787
# reviews_per_month          11787
# bedrooms                    5911
# description                  993
# host_is_superhost            440
# host_identity_verified        38
# host_verifications            38
# host_listings_count           38
# host_since                    38
# name                           2
# dtype: int64

# %% [markdown]
# * `license`

# %%
# creating binary column: 1 id the license is not NaN, 0 if it is NaN
df['has_license'] = df['license'].apply(lambda x: 1 if pd.notna(x) else 0)

# print the first 5 rows of the new column
print(df['has_license'].head())

# checking the unique values for the new column
print(df['has_license'].unique())

# getting the index of license column
license_index = df.columns.get_loc('license')

# moving the has_license column after the license column
df.insert(license_index + 1, 'has_license', df.pop('has_license'))

# dropping the license column
df.drop(columns=['license'], inplace=True)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: has_license, dtype: int64
# [0 1]

# %%
# !pip install missingno
import missingno as msno
# Out:
# Requirement already satisfied: missingno in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: numpy in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from missingno) (1.15.3)
# Requirement already satisfied: seaborn in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/irakli/anaconda3/envs/EDA-env/lib/python3.12/site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)

# %%
# getting the columns that have between 17210 and 11780 missing values
subset1_columns = df.columns[df.isna().sum().between(11780, 17210)].tolist()
print("Columns with missing values between 11780 and 17210:", subset1_columns)

# creating a subset of the dataframe with the columns that have between 11780 and 17210 missing values
subset1 = df[subset1_columns]

# visualising the missing values in the subset1 dataframe
msno.matrix(subset1, figsize=(12, 6))
# Out:
# Columns with missing values between 11780 and 17210: ['bathrooms', 'beds', 'price', 'estimated_revenue_l365d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_value', 'reviews_per_month']
# <Axes: >

# %% [markdown]
# # Neighbourhood

# %% [markdown]
# ### ok so description needs a cleaning with [.<br />An 8-minute walk to ] this kind of html format. has 900 missing values that can be dropped and then maybe use naive-bayes classifier to assign good place:badplace or some other description that is shorter than the full one.
#
# ### Same thing with neighborhood_overview
#
# ### Neighbourhood_cleansed can be used for plotting since it contians names of areas. there are same neighbourhoods as host_neighbourhood.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Identify the variable

# %% [markdown]
# ## 1) categorical -> nominal, ordinal. does it need encoding and what type of encoding is needed.
#
# ## 2) identify the numerical values (continous, discrete), importance of them in predictions, identify missing values in numerical values, think of ways to fill them. write the missing value implacements with reasoning and identofy dependencies between them.
#
# ## 3) Check out the unique values in each column, maybe there are some other types of variables or numpy nans.
#
# ## 4) Figure out the relationships between variables, what is depended on what and think of Techniques for rempalcement or feature engineering.
#
# ## 5) Modify column names because they are too long, assign reasonable names.
#
# ## 6) Dive into the features themselves, for example: is there a temporal pattern in reviews_per_month or availability_365 that suggests seasonal demand?

# %% [markdown]
# ## Potential Research Questions
#
# ### Price determinants: Which factors (location, room type, number of reviews, amenities) most strongly relate to  nightly price?
#
# ### Host activity: Do more experienced hosts (higher host_listings_count) charge differently or receive more reviews?
#
# ### Demand seasonality: Is there a temporal pattern in reviews_per_month or availability_365 that suggests seasonal demand?
#
# ### Review impact: How do review metrics (number_of_reviews, reviews_per_month, review_scores_rating) correlate with price and occupancy?
#
# #### Listing characteristics: Are certain property types (e.g. entire home vs private room) more common in specific neighborhoods or price tiers?

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Since there are 37K rows and 79 columns, Let's drop the rows of those features that hava the missing count of 15K. It would have been better to check if the data is MAR or MCAR but in this case the number of missing rows is the thing i took into account and decided to drop them, becasue this is AirBnb real world data and simply predictiong the missing values or imputing them in any way would be unreasonable.
# ### Also the type of rows taht are missing are from the most importnant features in the dataset like: price, bathrooms, beds, estimated revenue, neighbourhood.Dropping the rows from this features will not have that much of an importance to the other attributes since they are the important ones.

# %% [markdown]
# ## Strip the categorical columns that contain description or large texts so that cleaning process won't begin to have issues.

# %%
df['host_listings_count'].unique()
# Out:
# array([1.000e+00, 2.000e+00, 7.000e+00, 4.000e+00, 3.000e+00, 6.000e+00,
#        5.000e+00, 1.100e+01, 2.900e+01, 1.500e+01, 1.300e+01, 1.400e+01,
#        9.000e+00, 2.500e+01,       nan, 1.700e+01, 8.000e+00, 2.400e+01,
#        1.900e+01, 1.200e+01, 2.200e+01, 2.640e+02, 3.900e+01, 1.000e+01,
#        3.100e+01, 7.600e+01, 6.800e+01, 2.100e+01, 3.000e+01, 1.600e+01,
#        6.190e+02, 3.030e+02, 2.000e+01, 1.770e+02, 1.760e+02, 2.100e+02,
#        5.200e+01, 1.800e+01, 4.500e+01, 2.130e+02, 3.500e+01, 5.500e+01,
#        2.700e+01, 4.800e+01, 8.300e+01, 1.154e+03, 5.255e+03, 6.200e+02,
#        6.300e+01, 4.700e+01, 2.790e+02, 2.560e+02, 1.870e+02, 3.800e+01,
#        8.000e+01, 1.100e+02, 6.500e+01, 3.400e+01, 3.970e+02, 4.100e+01,
#        2.700e+02, 1.250e+02, 4.900e+01, 9.700e+01, 1.460e+02, 2.800e+01,
#        9.900e+01, 7.960e+02, 4.290e+02, 8.600e+01, 1.650e+02, 1.340e+02,
#        3.200e+01, 4.200e+01, 5.000e+01, 4.000e+01, 6.920e+02, 1.081e+03,
#        8.200e+01, 6.060e+02, 5.300e+01, 8.100e+01, 4.300e+01, 1.080e+02,
#        1.219e+03, 3.600e+01, 6.200e+01, 9.500e+01, 1.150e+02, 2.300e+01,
#        6.630e+02, 2.680e+02, 6.400e+01, 2.600e+01, 2.987e+03, 1.197e+03,
#        5.900e+01, 4.600e+01, 4.400e+02, 3.049e+03, 6.700e+02, 1.287e+03,
#        7.580e+02, 5.060e+02, 3.570e+02, 3.280e+02, 5.600e+01, 2.870e+03,
#        1.500e+02, 5.800e+01, 4.354e+03, 1.243e+03, 3.700e+01, 1.140e+02,
#        6.700e+01, 1.890e+02, 6.000e+01])

# %%
# Strip whitespace and convert prices
str_cols = df.select_dtypes(include='object').columns
df[str_cols] = df[str_cols].apply(lambda x: x.str.strip())

# %%
for col in ['price', 'cleaning_fee', 'extra_people']:
    if col in df.columns:
        df[col] = df[col].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_5312/741970556.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df[col] = df[col].replace('[\$,]', '', regex=True).astype(float)

# %% [markdown]
# ## Convert host_since, first_review, last_review columns into pandas Datetime and normalize

# %% [markdown]
# ## Add one more feature that is active days for simplicity

# %%
# Convert to datetime and normalize (remove time for calculations)
for col in ['host_since', 'first_review', 'last_review']:
    df[col] = pd.to_datetime(df[col], errors='coerce').dt.normalize()

# Optional: Create formatted string columns for display or export
df['host_duration_days'] = (pd.Timestamp.today() - df['host_since']).dt.days
df['active_days'] = (df['last_review'] - df['first_review']).dt.days
df['review_year'] = df['last_review'].dt.year
df['review_month'] = df['last_review'].dt.month
df['review_date'] = pd.to_datetime(df['review_year'].astype(str) + '-' + df['review_month'].astype(str) + '-01', errors='coerce')
# Out:
# /tmp/ipykernel_5312/963198197.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['review_date'] = pd.to_datetime(df['review_year'].astype(str) + '-' + df['review_month'].astype(str) + '-01', errors='coerce')

# %%
df['host_since'].unique()
# Out:
# <DatetimeArray>
# ['2009-12-11 00:00:00', '2010-07-04 00:00:00', '2010-07-13 00:00:00',
#  '2010-07-14 00:00:00', '2010-07-16 00:00:00', '2010-07-17 00:00:00',
#  '2008-09-09 00:00:00', '2009-05-06 00:00:00', '2009-05-07 00:00:00',
#  '2009-05-12 00:00:00',
#  ...
#  '2025-02-14 00:00:00', '2024-11-24 00:00:00', '2025-02-21 00:00:00',
#  '2025-02-20 00:00:00', '2025-02-25 00:00:00', '2025-02-11 00:00:00',
#  '2025-02-16 00:00:00', '2025-02-27 00:00:00', '2025-02-23 00:00:00',
#  '2024-03-16 00:00:00']
# Length: 5143, dtype: datetime64[ns]

# %% [markdown]
# ## Map the {True False} values to 0 and 1 for simplicity

# %%
df['host_is_superhost'].apply(lambda x: 1 if x == 't' else 0)
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 37429    0
# 37430    1
# 37431    0
# 37432    0
# 37433    1
# Name: host_is_superhost, Length: 37434, dtype: int64

# %% [markdown]
# ## add one more column that describes the popularity by review count

# %%
df['is_popular'] = (df['number_of_reviews'] > 100).astype(int)

# %% [markdown]
# ## Clean Description column from html formats

# %%
df['description'] = df['description'].replace('<br />', '').replace('<br/>', '').replace('<br>', '')

# %%
df['description'] = df['description'].fillna('')

# %% [markdown]
# ## Replaced numpy nan's and None's with pandas NaN, please dont critisize it is easier to see pandas NaN's

# %%
# Replace string 'NaN', 'nan', 'None' with actual np.nan
df.replace(['NaN', 'nan', 'None'], np.nan, inplace=True)

# %% [markdown]
# ## Now lets deal with missing values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# review_date                  37434
# estimated_revenue_l365d      15126
# price                        15126
# beds                         15082
# bathrooms                    14931
# review_scores_value          11804
# first_review                 11787
# review_month                 11787
# review_year                  11787
# active_days                  11787
# last_review                  11787
# review_scores_rating         11787
# reviews_per_month            11787
# bedrooms                      5911
# host_is_superhost              440
# host_since                      38
# host_verifications              38
# host_identity_verified          38
# host_duration_days              38
# host_listings_count             38
# name                             2
# instant_bookable                 0
# has_license                      0
# estimated_occupancy_l365d        0
# availability_30                  0
# number_of_reviews_ly             0
# availability_eoy                 0
# number_of_reviews                0
# availability_365                 0
# description                      0
# maximum_nights                   0
# minimum_nights                   0
# amenities                        0
# accommodates                     0
# room_type                        0
# longitude                        0
# latitude                         0
# neighbourhood_cleansed           0
# is_popular                       0
# dtype: int64

# %%
df.shape
# Out:
# (37434, 39)

# %% [markdown]
# ## Since the missing value count for the most imortant attributes are missing, especially they are not missing at the same time. For example the 17K missing values corresponding to the neighbourhood does not match the missing values inside host_response_time or any other column. So dropping them right away would clear ALL the rows that are.The another approach is to predict the missing values somehow and impute them, but the rows from those columns that are necessary for predictions of certain other features, are also missing.

# %% [markdown]
# ### The only thing left is to drop the missing values in a way to still retain several thousand rows.

# %%
# Defined the columns i was interested in
cols_to_check = ['price', 'beds', 'bathrooms', 'neighbourhood_cleansed', 'estimated_revenue_l365d']

# Droped rows where ALL of those are missing at the same time
df = df[~df[cols_to_check].isnull().all(axis=1)]

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# review_date                  37434
# estimated_revenue_l365d      15126
# price                        15126
# beds                         15082
# bathrooms                    14931
# review_scores_value          11804
# first_review                 11787
# review_month                 11787
# review_year                  11787
# active_days                  11787
# last_review                  11787
# review_scores_rating         11787
# reviews_per_month            11787
# bedrooms                      5911
# host_is_superhost              440
# host_since                      38
# host_verifications              38
# host_identity_verified          38
# host_duration_days              38
# host_listings_count             38
# name                             2
# instant_bookable                 0
# has_license                      0
# estimated_occupancy_l365d        0
# availability_30                  0
# number_of_reviews_ly             0
# availability_eoy                 0
# number_of_reviews                0
# availability_365                 0
# description                      0
# maximum_nights                   0
# minimum_nights                   0
# amenities                        0
# accommodates                     0
# room_type                        0
# longitude                        0
# latitude                         0
# neighbourhood_cleansed           0
# is_popular                       0
# dtype: int64

# %%
df = df.dropna(subset=cols_to_check)

# %% [markdown]
# ## So we are left with 10K rows from 37K which is huge reduction, but the dataset is really messy and we had time till today.

# %%
df.shape
# Out:
# (22223, 39)

# %%
df.isna().sum().sort_values(ascending=False)[:15]
# Out:
# review_date               22223
# review_month               6773
# review_scores_rating       6773
# last_review                6773
# first_review               6773
# reviews_per_month          6773
# active_days                6773
# review_year                6773
# review_scores_value        6773
# host_is_superhost           372
# bedrooms                     48
# host_identity_verified       20
# host_verifications           20
# host_listings_count          20
# host_since                   20
# dtype: int64

# %% [markdown]
# ## Checking the rows of columns that still have missing values to find the way to impute them.

# %% [markdown]
# ## Since the reviews do not exceed 5.0 and they are somewhat according to the real-life scenario, lets impute the missings with Median.

# %%
float_columns = ['review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value']

# %%
df.isna().sum().sort_values(ascending=False)[:8]
# Out:
# review_date             22223
# review_month             6773
# review_scores_rating     6773
# last_review              6773
# first_review             6773
# reviews_per_month        6773
# active_days              6773
# review_year              6773
# dtype: int64

# %% [markdown]
# ## some columns related to reviews are supposed to be Datetime objects, i will handle this later on

# %%
df['first_review'].unique()
# Out:
# <DatetimeArray>
# ['2010-12-11 00:00:00', '2010-10-04 00:00:00', '2012-07-09 00:00:00',
#  '2010-08-28 00:00:00', '2010-08-02 00:00:00', '2009-05-25 00:00:00',
#  '2022-06-05 00:00:00', '2009-10-28 00:00:00', '2010-01-16 00:00:00',
#  '2009-08-09 00:00:00',
#  ...
#  '2025-02-14 00:00:00', '2025-01-30 00:00:00', '2025-01-27 00:00:00',
#  '2024-12-24 00:00:00', '2025-01-28 00:00:00', '2025-02-03 00:00:00',
#  '2024-12-03 00:00:00', '2025-02-08 00:00:00', '2025-02-26 00:00:00',
#  '2025-02-13 00:00:00']
# Length: 3754, dtype: datetime64[ns]

# %%
df['last_review'].unique()
# Out:
# <DatetimeArray>
# ['2013-05-10 00:00:00', '2023-12-09 00:00:00', '2023-08-30 00:00:00',
#  '2025-02-21 00:00:00', '2025-01-03 00:00:00', '2024-10-05 00:00:00',
#  '2022-06-05 00:00:00', '2024-12-01 00:00:00', '2025-02-28 00:00:00',
#  '2024-07-31 00:00:00',
#  ...
#  '2024-06-25 00:00:00', '2024-04-18 00:00:00', '2023-06-16 00:00:00',
#  '2024-03-19 00:00:00', '2023-06-22 00:00:00', '2024-02-25 00:00:00',
#  '2024-02-20 00:00:00', '2024-01-29 00:00:00', '2024-01-28 00:00:00',
#  '2024-02-21 00:00:00']
# Length: 1691, dtype: datetime64[ns]

# %% [markdown]
# ## Replace the price range from 0 to 25 as 25, it's a puris fuli

# %%
df['price'].replace(range(0, 25), 25, inplace=True)
# Out:
# /tmp/ipykernel_5312/416184499.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].replace(range(0, 25), 25, inplace=True)

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_5312/2337335738.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df.select_dtypes(include='float64').columns
# Out:
# Index(['host_listings_count', 'latitude', 'longitude', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'estimated_revenue_l365d', 'review_scores_rating',
#        'review_scores_value', 'reviews_per_month', 'host_duration_days',
#        'active_days', 'review_year', 'review_month'],
#       dtype='object')

# %% [markdown]
# ## There were no missing values in float columns except bedrooms i think, the count was 20 so i dropped it also.

# %%
transform_integer_columns = ['bathrooms', 'bedrooms', 'beds', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights','host_duration_days', 'active_days'
]

# %%
df['bedrooms'].dropna(inplace=True)

# %%
df.shape
# Out:
# (22223, 39)

# %% [markdown]
# ## Outlier detection

# %% [markdown]
# ## Catch outliers with boxplot

# %%
df.columns
# Out:
# Index(['name', 'description', 'host_since', 'host_is_superhost',
#        'host_listings_count', 'host_verifications', 'host_identity_verified',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_365', 'number_of_reviews', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_value', 'has_license',
#        'instant_bookable', 'reviews_per_month', 'host_duration_days',
#        'active_days', 'review_year', 'review_month', 'review_date',
#        'is_popular'],
#       dtype='object')

# %%
q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
iqr = q3 -q1

lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

outliers = df[(df['price'] < lower_whisker) | (df['price'] > upper_whisker)]

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ## In this data, extremely high prices may be luxury listings, not errors. Very low prices may be shared rooms or data entry mistakes.

# %%
df['log_price'] = np.log1p(df['price'])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['price'], bins=40, kde=True)
plt.title('Original Price Distribution')

plt.subplot(1,2,2)
sns.histplot(df['log_price'], bins=40, kde=True, color='orange')
plt.title('Log-Transformed Price Distribution')
plt.show()

# %%
sns.scatterplot(x='accommodates', y='log_price', data=df)
plt.title('Log Price vs. Accommodates')
plt.show()

# %% [markdown]
# ## Price Determinants: Which factors (location, room type, number of reviews, amenities) most strongly relate to nightly price?

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder

x = df[['accommodates', 'number_of_reviews', 'reviews_per_month', 'availability_365', 'host_listings_count']]
x = pd.concat([x, pd.get_dummies(df['room_type']), pd.get_dummies(df['neighbourhood_cleansed'])], axis=1)

y = df['log_price']

rf = RandomForestRegressor(n_estimators=100, random_state=42)   
rf.fit(x, y)

importances = pd.Series(rf.feature_importances_, index=x.columns)
importances.sort_values(ascending=False).head(10).plot(kind='barh')
plt.title('Top 10 Feature Importances for Log Price')
plt.show()

# %% [markdown]
# ## Host Activity: Do more experienced hosts (higher host_listings_count) charge differently or receive more reviews?

# %%
sns.scatterplot(x='host_listings_count', y='price', data=df)
plt.title('Host Listings Count vs. Price')
plt.show()

# %%
sns.scatterplot(x='host_listings_count', y='number_of_reviews', data=df)
plt.title('Host Listings Count vs. Number of Reviews')
plt.show()

# %%
print(df[['host_listings_count', 'log_price', 'number_of_reviews']].corr())
# Out:
#                      host_listings_count  log_price  number_of_reviews
# host_listings_count             1.000000   0.351107          -0.137032
# log_price                       0.351107   1.000000          -0.047957
# number_of_reviews              -0.137032  -0.047957           1.000000

# %% [markdown]
# ## Demand Seasonality: Is there a temporal pattern in reviews_per_month or availability_365 that suggests seasonal demand?

# %%
monthly_reviews_avg = df.groupby('review_month')['reviews_per_month'].median()
plt.figure(figsize=(10, 5))
monthly_reviews_avg.plot(kind='bar', color='#4B0082')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.title('Average Reviews per Month by Month')
plt.xlabel('Month')
plt.ylabel('Average Reviews per Month')
plt.grid(True)
plt.show()

# %%
df_reviews = df[df['last_review'].notna() & df['reviews_per_month'].notna()].copy()
monthly_series = df_reviews.groupby('review_date')['reviews_per_month'].mean().asfreq('MS', fill_value=0)
if len(monthly_series) >= 24:
    decomposition = seasonal_decompose(monthly_series, model='additive', period=12)
    fig = decomposition.plot()
    fig.set_size_inches(12, 8)
    plt.show()
else:
    print(f"Insufficient data for seasonal decomposition: {len(monthly_series)} observations. Need at least 24.")
# Out:
# Insufficient data for seasonal decomposition: 0 observations. Need at least 24.

# %%
availability_by_month = df.groupby('review_month')['availability_365'].mean()
plt.figure(figsize=(10, 5))
availability_by_month.plot(kind='bar', color='green')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.title('Average Availability (365 Days) by Month')
plt.xlabel('Month')
plt.ylabel('Average Availability')
plt.grid(True)
plt.show()

# %%
monthly_reviews = (
    df.groupby('last_review')['reviews_per_month']
    .mean()
)

# %%
trend_2024 = monthly_reviews.rolling(window=3, center=True).mean()

# --- Step 3: Plot everything ---
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_reviews.index, y=monthly_reviews.values, label="Actual", marker='o')
sns.lineplot(x=trend_2024.index, y=trend_2024.values, label="Trend (3-mo rolling avg)", linestyle='--')

plt.title("Average Monthly Reviews in 2024 with Trend")
plt.xlabel("Month")
plt.ylabel("Average Reviews Per Month")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Ensure date columns are datetime
df['last_review']  = pd.to_datetime(df['last_review'],  errors='coerce')
df['first_review'] = pd.to_datetime(df['first_review'], errors='coerce')

# 2. Drop rows missing the key metrics
df_ts = df.dropna(subset=['last_review', 'reviews_per_month', 'review_scores_rating'])

# 3. Set 'last_review' as index and resample by month
monthly = (
    df_ts
      .set_index('last_review')
      .resample('M')
      .agg({
          'reviews_per_month': 'mean',
          'review_scores_rating': 'mean',
          'number_of_reviews': 'sum'
      })
      .rename(columns={
          'reviews_per_month': 'avg_reviews_per_month',
          'review_scores_rating': 'avg_rating',
          'number_of_reviews': 'total_reviews'
      })
)

# 4. Plotting
plt.figure(figsize=(14, 6))

# Reviews per month
plt.subplot(2, 1, 1)
sns.lineplot(
    x=monthly.index,
    y=monthly['avg_reviews_per_month'],
    marker='o'
)
plt.title('Monthly Average Reviews per Month')
plt.ylabel('Avg Reviews / Month')
plt.grid(True)

# Rating over time
plt.subplot(2, 1, 2)
sns.lineplot(
    x=monthly.index,
    y=monthly['avg_rating'],
    marker='o',
    color='green'
)
plt.title('Monthly Average Review Score')
plt.ylabel('Avg Rating')
plt.xlabel('Date')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5312/2270035075.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample('M')

# %%
price_by_month = df.groupby('review_month')['log_price'].median()
plt.figure(figsize=(10, 5))
price_by_month.plot(kind='bar', color='#FF4500')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.title('Median Log Price by Month')
plt.xlabel('Month')
plt.ylabel('Median Log Price')
plt.grid(True)
plt.show()

# %%
df['neighbourhood_cleansed'].unique()
# Out:
# array(['Prospect Heights', 'East Harlem', 'Boerum Hill', 'Harlem',
#        'Williamsburg', 'Fort Greene', 'Bedford-Stuyvesant',
#        'Crown Heights', 'Clinton Hill', 'Chelsea', 'Washington Heights',
#        'Gowanus', 'Lower East Side', 'Carroll Gardens', 'Midtown',
#        "Hell's Kitchen", 'Greenpoint', 'East Village', 'Ridgewood',
#        'Mott Haven', 'Morningside Heights', 'Rockaway Beach',
#        'Park Slope', 'Upper East Side', 'West Village', 'Flatbush',
#        'Ditmars Steinway', 'Middle Village', 'Astoria', 'South Slope',
#        'Brooklyn Heights', 'Upper West Side', 'Chinatown', 'Bensonhurst',
#        'Clason Point', 'Eastchester', 'Windsor Terrace', 'Gravesend',
#        'Shore Acres', 'Kips Bay', 'Nolita', 'Kingsbridge', 'Bushwick',
#        'Greenwich Village', 'Sheepshead Bay', 'Sunset Park', 'Sunnyside',
#        'Prospect-Lefferts Gardens', 'Downtown Brooklyn', 'Tribeca',
#        'Co-op City', 'Kensington', 'Woodside', 'East New York', 'Inwood',
#        'Long Island City', 'SoHo', 'Spuyten Duyvil', 'Briarwood',
#        'Red Hook', 'Two Bridges', 'Tompkinsville', 'Gramercy', 'Allerton',
#        'Murray Hill', 'Tottenville', 'Bayside', 'College Point',
#        'Concord', 'Flushing', 'Jackson Heights', 'DUMBO', 'City Island',
#        'East Elmhurst', 'Norwood', 'Concourse', 'Cobble Hill',
#        'Port Morris', 'East Flatbush', 'Arverne', 'Richmond Hill',
#        'Maspeth', 'Longwood', 'Financial District', 'Soundview',
#        'Queens Village', 'Canarsie', 'Theater District', 'Rego Park',
#        'Sea Gate', 'Flatlands', 'Bay Terrace', 'Jamaica',
#        'Battery Park City', 'Woodhaven', 'Fieldston', 'Mount Hope',
#        'Huguenot', 'Concourse Village', 'Midwood', 'St. George',
#        'Ozone Park', 'Civic Center', 'Vinegar Hill', 'Bay Ridge',
#        'Roosevelt Island', 'Forest Hills', 'Elmhurst', 'Lighthouse Hill',
#        'Randall Manor', 'NoHo', 'Unionport', 'Borough Park',
#        'Columbia St', 'Flatiron District', 'South Ozone Park', 'Clifton',
#        'Cypress Hills', 'West Brighton', 'Jamaica Estates',
#        'Manhattan Beach', 'Kew Gardens', 'Springfield Gardens',
#        'Brownsville', 'Hunts Point', 'Fort Hamilton', 'Howard Beach',
#        'Fresh Meadows', 'Great Kills', 'Bellerose', 'Holliswood',
#        'Bronxdale', 'Corona', 'Little Italy', 'Edgemere',
#        'Castleton Corners', 'New Brighton', 'Baychester', 'Wakefield',
#        'Brighton Beach', 'Stuyvesant Town', 'St. Albans',
#        'Claremont Village', 'Highbridge', 'South Beach', 'Rosedale',
#        'Howland Hook', 'Pelham Gardens', 'Kew Gardens Hills',
#        'Dyker Heights', 'Arrochar', 'Laurelton', 'Morris Park', 'Fordham',
#        'Coney Island', 'Tremont', 'Whitestone', 'Edenwald', 'Bath Beach',
#        'Stapleton', 'Olinville', 'Mount Eden', 'Glendale',
#        'Fort Wadsworth', 'Pelham Bay', 'Morrisania', 'Marble Hill',
#        'Hollis', 'Williamsbridge', 'East Morrisania', 'Melrose',
#        'Westchester Square', 'Neponsit', 'North Riverdale', 'Throgs Neck',
#        'Mariners Harbor', 'Port Richmond', 'Willowbrook', 'Parkchester',
#        'Mill Basin', 'Douglaston', 'Midland Beach', 'Bergen Beach',
#        'Schuylerville', 'New Dorp Beach', 'Rosebank', 'Arden Heights',
#        'Belmont', 'Far Rockaway', 'Morris Heights', 'Grymes Hill',
#        'Emerson Hill', 'Cambria Heights', 'Grant City', "Prince's Bay",
#        'New Springville', 'Navy Yard', 'Jamaica Hills', "Bull's Head",
#        'Woodlawn', 'Belle Harbor', 'Silver Lake', 'Riverdale',
#        'Bayswater', 'Gerritsen Beach', 'Breezy Point', 'Westerleigh',
#        'Graniteville', 'Chelsea, Staten Island', 'University Heights',
#        'Van Nest', 'Castle Hill', 'West Farms', 'Todt Hill',
#        'Eltingville', 'Woodrow', 'Oakwood', 'Dongan Hills', 'Rossville',
#        'Country Club', 'Little Neck'], dtype=object)

# %%
df_price_trends = df[df['last_review'].notna() & df['log_price'].notna() & df['neighbourhood_cleansed'].notna()].copy()
print("Shape of df_price_trends:", df_price_trends.shape)
print("Missing values in df_price_trends:")
print(df_price_trends[['last_review', 'review_date', 'log_price', 'neighbourhood_cleansed']].isna().sum())

# If no data, exit early with a message
if df_price_trends.empty:
    print("No data available for price trend analysis. Check if 'last_review', 'log_price', or 'neighbourhood_cleansed' have valid values.")
else:
    # Extract year-month for grouping
    df_price_trends['year_month'] = df_price_trends['last_review'].dt.to_period('M').dt.to_timestamp()
    print("Unique year-month values:", df_price_trends['year_month'].dt.to_period('M').unique())

    # Select specific neighborhoods (including Manhattan and others in NYC)
    nyc_neighborhoods = ['Crown Heights',  'Brooklyn Heights', 'East New York', 'Long Island City']
    # Filter for neighborhoods present in the data
    available_neighborhoods = [n for n in nyc_neighborhoods if n in df_price_trends['neighbourhood_cleansed'].values]
    print("Available NYC neighborhoods:", available_neighborhoods)

    if not available_neighborhoods:
        print("None of the specified NYC neighborhoods (Manhattan, Brooklyn, etc.) found in the data.")
    else:
        # Group by neighborhood and year-month, calculate median log_price
        price_by_neighborhood = df_price_trends.groupby(['neighbourhood_cleansed', 'year_month'])['log_price'].median().reset_index()

        # Plot price trends for available neighborhoods
        plt.figure(figsize=(14, 8))
        for neighborhood in available_neighborhoods:
            subset = price_by_neighborhood[price_by_neighborhood['neighbourhood_cleansed'] == neighborhood]
            if not subset.empty:
                plt.plot(subset['year_month'], subset['log_price'], marker='o', label=neighborhood)
            else:
                print(f"No price data for {neighborhood}")

        plt.title('Median Log Price Trends by Neighborhood Over Time')
        plt.xlabel('Year-Month')
        plt.ylabel('Median Log Price')
        plt.legend(title='Neighborhood')
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
# Out:
# Shape of df_price_trends: (15450, 41)
# Missing values in df_price_trends:
# last_review                   0
# review_date               15450
# log_price                     0
# neighbourhood_cleansed        0
# dtype: int64
# Unique year-month values: <PeriodArray>
# ['2013-05', '2023-12', '2023-08', '2025-02', '2025-01', '2024-10', '2022-06',
#  '2024-12', '2024-07', '2023-10',
#  ...
#  '2018-12', '2020-08', '2016-11', '2017-07', '2018-11', '2017-04', '2021-04',
#  '2019-03', '2019-02', '2018-02']
# Length: 133, dtype: period[M]
# Available NYC neighborhoods: ['Crown Heights', 'Brooklyn Heights', 'East New York', 'Long Island City']

# %%
# Specific focus on Manhattan
manhattan_prices = price_by_neighborhood[price_by_neighborhood['neighbourhood_cleansed'] == 'Manhattan']
if not manhattan_prices.empty:
    plt.figure(figsize=(10, 6))
    plt.plot(manhattan_prices['year_month'], manhattan_prices['log_price'], marker='o', color='blue')
    plt.title('Median Log Price Trend in Manhattan')
    plt.xlabel('Year-Month')
    plt.ylabel('Median Log Price')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
        print("No data available for Manhattan in the specified time frame.")
# Out:
# No data available for Manhattan in the specified time frame.

# %%
# Filter for March 2015
march_2015_df = df[
    (df['last_review'].dt.year == 2015) &
    (df['last_review'].dt.month == 3)
].copy()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='room_type', data=march_2015_df)
plt.title('Room Type Distribution (March 2015)')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='accommodates', y='price', data=march_2015_df)
plt.title('Price vs. Accommodates (March 2015)')
plt.xlabel('Accommodates')
plt.ylabel('Price')
plt.show()

# %%
number_of_rows_2015_march = march_2015_df.shape[0]
print(f"Number of rows with last_review in March 2015: {number_of_rows_2015_march}")
# Out:
# Number of rows with last_review in March 2015: 1

# %% [markdown]
# ##  Review Impact: How do review metrics (number_of_reviews, reviews_per_month, review_scores_rating) correlate with price and occupancy?

# %%
neigh_price = df.groupby('neighbourhood_cleansed')['log_price'].median()
df['neigh_log_price_mean'] = df['neighbourhood_cleansed'].map(neigh_price)

# 2. Select features for heatmap
selected = ['log_price', 'accommodates', 'bedrooms', 'bathrooms', 'reviews_per_month', 'availability_365', 'neigh_log_price_mean']
small_corr = df[selected].corr(method='spearman')
plt.figure(figsize=(8,6))
sns.heatmap(small_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Spearman Correlation Heatmap (Including Neighbourhood Median Price)')
plt.show()

# %% [markdown]
# ## Listing Characteristics: Are certain property types (e.g. entire home vs private room) more common in specific neighborhoods or price tiers?

# %%
sample_df = df.sample(n=10000, random_state=42)

plt.figure(figsize=(14, 6))
sns.countplot(data=sample_df, x='neighbourhood_cleansed', hue='room_type',
              order=sample_df['neighbourhood_cleansed'].value_counts().index[:10])  # Top 10 neighborhoods
plt.title('Room Type Distribution Across Neighborhoods')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Select features (including location)
features = ['log_price', 'accommodates', 'bedrooms', 'bathrooms', 'number_of_reviews', 'latitude', 'longitude']
X = df[features].dropna()

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA
pca = PCA(n_components=2)
pcs = pca.fit_transform(X_scaled)

# Add PCA results to DataFrame
df_pca = df.loc[X.index].copy()
df_pca['PC1'] = pcs[:, 0]
df_pca['PC2'] = pcs[:, 1]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='PC1', y='PC2', hue='log_price', data=df_pca, palette='viridis', alpha=0.7)
plt.show()

# %%
import folium

# Center the map on the mean latitude and longitude of your listings
map_center = [df['latitude'].mean(), df['longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Add each listing as a circle marker
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.6,
        popup=f"Price: {row['price']}"  # You can customize this popup
    ).add_to(m)

# Save the map to an HTML file
m.save('airbnb_map.html')

# %%
df['neighbourhood_cleansed'].iloc[3]
# Out:
# 'Harlem'

# %%
import folium

df1 = df.sample(random_state=42, n=500, ignore_index=True)
# Center of map (mean coordinates or fixed point)
center_lat = df1['latitude'].mean()
center_lon = df1['longitude'].mean()

# Create map object
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Add markers
for idx, row in df1.iterrows():
    popup_text = f"""
    <b>Location:</b> {row.get('latitude', 'N/A')}<br>
    <b>Location:</b> {row.get('longitude', 'N/A')}<br>
    <b>Price:</b> {row.get('price', 'N/A')}<br>
    <b>Neighbourhood:</b> {row.get('neighbourhood_cleansed', 'N/A')}<br>
    <b>Review Score:</b> {row.get('review_scores_accuracy', 'N/A')}<br>
    <b>Review count:</b> {row.get('number_of_reviews', 'N/A')}<br>
    
    <b>Desctiption:</b> {row.get('description', 'N/A')}<br>

    """
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=row.get('address', 'Click for details')
    ).add_to(m)

# Save to HTML
m.save('apartments_map.html')

# %%
df['description'].iloc[3]
# Out:
# 'This is a very large and unique  space. An incredibly quiet apartment on one of the nicest blocks in Manhattan. Its a very spacious (800 sq ft)  home with an 800 sq ft garden /patio with right outside your bedroom door ! Despite the country-quiet, you are only 100 feet away from the subway which gets you in to the center of Manhattan in 8-10 minutes..'

# %% [markdown]
# ## Let's do text summarizer for description column since not many people are gonna read the whole description of apartaments, during the search. Just the keywords and reasonable summary would be sufficinet.
